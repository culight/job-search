# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.insert(0, '..')
from job_search.data.extract import ExtractionHandler

# %%
site_name = "glassdoor"
search_term = "data engineer"
location = "Chicago, IL"

eh = ExtractionHandler()
jobs = eh.extract_jobs(site_name, search_term, location)
jobs
# Out:
#                                              job_url       site  \
# 0  https://www.glassdoor.com/job-listing/principa...  glassdoor
# 1  https://www.glassdoor.com/job-listing/manager-...  glassdoor
# 2  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 3  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 4  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 5  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 6  https://www.glassdoor.com/job-listing/senior-d...  glassdoor
# 7  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 8  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
# 9  https://www.glassdoor.com/job-listing/data-eng...  glassdoor
#
#                                                title  \
# 0  Principal Associate, Data Loss Prevention (DLP...
# 1  Manager, Data Loss Prevention (DLP) Engineer (...
# 2                                    Data Engineer I
# ...

# %%
jobs.count()[0] == 0
# Out:
# /var/folders/3_/sg9g481d2c38p7t6gsc7wkyr0000gn/T/ipykernel_11594/1574595001.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   jobs.count()[0] == 0
# False

# %%
eh.load_jobs(jobs, "test")

# %%
eh.extract_and_load_jobs(site_name="glassdoor", search_term="gcp", location="chicago, il", is_remote=True, results_wanted=100)
# Out:
# 2023-12-12 15:23:27,791 - Loading jobs...
# /Users/djm/projects/data_projects/job-search/test/../job_search/data/extract.py:140: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if count := jobs.count()[0] == 0:
# 2023-12-12 15:23:32,917 - Loaded False jobs
# 2023-12-12 15:23:32,917 - Uploading file to None/gcp/glassdoor_0-100
# 2023-12-12 15:23:35,853 - File successfully uploaded
# 2023-12-12 15:23:35,857 - Loading jobs...
# /Users/djm/projects/data_projects/job-search/test/../job_search/data/extract.py:140: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if count := jobs.count()[0] == 0:
# ...

# %%
eh.extract_and_load_jobs(site_name="indeed", search_term="gcp", location="chicago, il", is_remote=True, results_wanted=100)
# Out:
# 2023-12-12 15:11:44,254 - Loading jobs...
# 2023-12-12 15:12:13,630 - bad response with status code: 429

# %%
eh.extract_and_load_jobs(site_name="zip_recruiter", search_term="bigquery", location="chicago, il", results_wanted=100)
# Out:
# 2023-12-12 15:12:13,930 - Loading jobs...
# 2023-12-12 15:12:14,038 - bad response status code: 403

# %%
eh.extract_and_load_jobs(site_name="linkedin", search_term="gcp", location="chicago, il", is_remote=True, results_wanted=100)
# Out:
# 2023-12-12 15:24:48,503 - Loading jobs...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/djm/projects/data_projects/job-search/test/sandbox.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/djm/projects/data_projects/job-search/test/sandbox.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> eh.extract_and_load_jobs(site_name="linkedin", search_term="gcp", location="chicago, il", results_wanted=100)
#
# File ~/projects/data_projects/job-search/test/../job_search/data/extract.py:130, in ExtractionHandler.extract_and_load_jobs(self, site_name, search_term, location, results_wanted, offset, country_indeed, country_glassdoor, bucket_name, **scrape_params)
#     128 LOGGER.info("Loading jobs...")
#     129 try:
# --> 130     jobs = self.extract_jobs(
#     131         site_name=site_name,
#     132         search_term=search_term,
#     133         location=location,
# ...

# %%
search_details = {
    "site_names": extract.VALID_SOURCES,
    "search_terms": ["data engineer", "analytics engineer", "database engineer"],
    "locations": ["chicago, il", "remote"],
}
# Out:
#                                              job_url    site  \
# 0  https://www.indeed.com/viewjob?jk=321cfaca1294...  indeed
# 1  https://www.indeed.com/viewjob?jk=9db8a3b444d7...  indeed
# 2  https://www.indeed.com/viewjob?jk=5aafa2752442...  indeed
# 3  https://www.indeed.com/viewjob?jk=bc83fc8d0f0c...  indeed
# 4  https://www.indeed.com/viewjob?jk=30ed2c755224...  indeed
# 5  https://www.indeed.com/viewjob?jk=924915794859...  indeed
# 6  https://www.indeed.com/viewjob?jk=f237196940ec...  indeed
# 7  https://www.indeed.com/viewjob?jk=19c17208a90c...  indeed
# 8  https://www.indeed.com/viewjob?jk=759da2ffc5a7...  indeed
# 9  https://www.indeed.com/viewjob?jk=0de2adbfd5c1...  indeed
#
#                title                      company company_url  \
# 0      Data Engineer                  LTIMindtree        None
# 1  Platform Engineer             Publicis Sapient        None
# 2      Data Engineer                 StoneX Group        None
# ...
