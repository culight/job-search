# %%
# %load_ext autoreload
# %autoreload 2

# %%
from job_search._tools.io import RESTClient, GCSClient
from job_search._tools.extract import extract_jobs_scrape

# %%
jobs = extract_jobs_scrape(site_name="indeed", search_term="data engineer", location="Chicago, IL", results_wanted=10)

# %%
jobs
# Out:
#                                              job_url    site  \
# 0  https://www.indeed.com/viewjob?jk=c8dc637046ea...  indeed
# 1  https://www.indeed.com/viewjob?jk=ec7f981cce48...  indeed
# 2  https://www.indeed.com/viewjob?jk=af0cc1573704...  indeed
# 3  https://www.indeed.com/viewjob?jk=1eb5945f57a1...  indeed
# 4  https://www.indeed.com/viewjob?jk=69c97f2cd1ea...  indeed
# 5  https://www.indeed.com/viewjob?jk=e0353ad883b0...  indeed
# 6  https://www.indeed.com/viewjob?jk=6a0e7663fd92...  indeed
# 7  https://www.indeed.com/viewjob?jk=35a7e53957cd...  indeed
# 8  https://www.indeed.com/viewjob?jk=f848260d4e85...  indeed
# 9  https://www.indeed.com/viewjob?jk=0de2adbfd5c1...  indeed
#
#                    title              company company_url            location  \
# 0          Data Engineer             MedSpeed        None   Elmhurst, IL, USA
# 1          Data Engineer        Kin Insurance        None    Chicago, IL, USA
# ...
